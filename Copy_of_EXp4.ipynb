# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenn018/NLP/blob/main/Copy_of_EXp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re

# %%
data= pd.read_csv('/content/twitter4000.csv')

# %%
pattern = r'\w+@\w+.\w+'

# %%
pattern=r'\b[A-Za-z._+-]+@[A-za-z].[A-Z|a-z]{2,}\b'

# %%
data['email']=data['twitts'].apply(lambda x: re.findall(pattern=pattern,string=x))
data['email'].sample(5)
# Out:
# 2225    []
# 2714    []
# 1506    []
# 3009    []
# 3177    []
# Name: email, dtype: object
