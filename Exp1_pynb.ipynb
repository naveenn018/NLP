# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenn018/NLP/blob/main/Exp1_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
text = "I am God . God is great."
output1 = word_tokenize(text)
print(output1)
# Out:
# ['I', 'am', 'God', '.', 'God', 'is', 'great', '.']
